# %%
import os

# %%
files_hsp = os.listdir('../../Body/2_Derived/hsps/PAML_output/')
to_rerun_hsp = []

for file in files_hsp[1:]:
    #print(file)
    out = open('../../Body/2_Derived/hsps/PAML_output/' + file).readlines()
    if 'Time used' in out:
        print(file)
        print(out[-1])
    #print()
    
    #if 'Time used' in out[-1]:
        #to_rerun_hsp.append(file)
        
#with open('../../Body/2_Derived/hsps/success.txt', 'w') as f:
#    for line in to_rerun_hsp:
#        f.write(line + '\n')
#    f.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-4-8709b79706c1> in <module>
#       4 for file in files_hsp[1:]:
#       5     #print(file)
# ----> 6     out = open('../../Body/2_Derived/hsps/PAML_output/' + file).readlines()
#       7     if 'Time used' in out:
#       8         print(file)
#
# PermissionError: [Errno 13] Permission denied: '../../Body/2_Derived/hsps/PAML_output/success'

# %%
files = os.listdir('../../Body/2_Derived/nonhsp/PAML_output/')
to_rerun = []

for file in files[1:]:
    #print(file)
    out = open('../../Body/2_Derived/nonhsp/PAML_output/' + file).readlines()
    if out == []:
        #to_rerun.append(file)
        print('blanck')
        print()
    else:
        #print('Time used' in out[-1])
        #print()
    
        if 'Time used' in out:
            print(file)
            to_rerun.append(file)
        
#with open('../../Body/2_Derived/nonhsp/success.txt', 'w') as f:
#   for line in to_rerun:
#        f.write(line + '\n')
#    f.close()
# Out:
# blanck
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-c0f3ed146563> in <module>
#       4 for file in files[1:]:
#       5     #print(file)
# ----> 6     out = open('../../Body/2_Derived/nonhsp/PAML_output/' + file).readlines()
#       7     if out == []:
#       8         #to_rerun.append(file)
#
# PermissionError: [Errno 13] Permission denied: '../../Body/2_Derived/nonhsp/PAML_output/success'

# %%
files = os.listdir('../../Body/2_Derived/clients/PAML_output/')
files = files[:-1]
to_rerun = []

for file in files[1:]:
    print(file)
    out = open('../../Body/2_Derived/clients/PAML_output/' + file).readlines()
    if out == []:
        #to_rerun.append(file)
        print('blanck')
        print()
    else:
        print('Time used' in out[-1])
        print()
    
        if 'Time used' in out[-1]:
            to_rerun.append(file)
        
with open('../../Body/2_Derived/clients/success.txt', 'w') as f:
    for line in to_rerun:
        f.write(line + '\n')
    f.close()
# Out:
# ENSG00000004455_AK2_NT.txt
# False
#
# ENSG00000009765_IYD_NT.txt
# True
#
# ENSG00000010671_BTK_NT.txt
# True
#
# ENSG00000012124_CD22_NT.txt
# True
#
# ENSG00000049130_KITLG_NT.txt
# False
#
# ENSG00000069011_PITX1_NT.txt
# False
#
# ENSG00000076242_MLH1_NT.txt
# False
#
# ENSG00000087245_MMP2_NT.txt
# True
#
# ENSG00000087460_GNAS_NT.txt
# False
#
# ENSG00000094914_AAAS_NT.txt
# False
#
# ENSG00000100979_PLTP_NT.txt
# False
#
# ENSG00000101144_BMP7_NT.txt
# True
#
# ENSG00000101670_LIPG_NT.txt
# False
#
# ENSG00000105088_OLFM2_NT.txt
# False
#
# ENSG00000105221_AKT2_NT.txt
# True
#
# ENSG00000105370_LIM2_NT.txt
# False
#
# ENSG00000106003_LFNG_NT.txt
# True
#
# ENSG00000106100_NOD1_NT.txt
# False
#
# ENSG00000106692_FKTN_NT.txt
# False
#
# ENSG00000107290_SETX_NT.txt
# True
#
# ENSG00000108370_RGS9_NT.txt
# True
#
# ENSG00000109424_UCP1_NT.txt
# True
#
# ENSG00000112357_PEX7_NT.txt
# True
#
# ENSG00000113263_ITK_NT.txt
# True
#
# ENSG00000114739_ACVR2B_NT.txt
# False
#
# ...

# %%
# Out:
# 69

# %%
files = os.listdir('../../Body/2_Derived/nonclients/PAML_output/')
to_rerun = []

for file in files[1:]:
    print(file)
    out = open('../../Body/2_Derived/nonclients/PAML_output/' + file).readlines()
    if out == []:
        to_rerun.append(file)
        print('blanck')
        print()
    else:
        print('Time used' in out[-1])
        print()
    
        if 'Time used' in out[-1]:
            to_rerun.append(file)
        
with open('../../Body/2_Derived/nonclients/seccess.txt', 'w') as f:
    for line in to_rerun:
        f.write(line + '\n')
    f.close()
# Out:
# ENSG00000004961_HCCS_NT.txt
# True
#
# ENSG00000009709_PAX7_NT.txt
# False
#
# ENSG00000012174_MBTPS2_NT.txt
# False
#
# ENSG00000014123_UFL1_NT.txt
# False
#
# ENSG00000017427_IGF1_NT.txt
# True
#
# ENSG00000028277_POU2F2_NT.txt
# False
#
# ENSG00000029364_SLC39A9_NT.txt
# True
#
# ENSG00000059378_PARP12_NT.txt
# False
#
# ENSG00000060982_BCAT1_NT.txt
# False
#
# ENSG00000067836_ROGDI_NT.txt
# False
#
# ENSG00000068903_SIRT2_NT.txt
# False
#
# ENSG00000069018_TRPC7_NT.txt
# False
#
# ENSG00000070610_GBA2_NT.txt
# False
#
# ENSG00000071537_SEL1L_NT.txt
# False
#
# ENSG00000072952_MRVI1_NT.txt
# True
#
# ENSG00000075290_WNT8B_NT.txt
# False
#
# ENSG00000075420_FNDC3B_NT.txt
# False
#
# ENSG00000076003_MCM6_NT.txt
# False
#
# ENSG00000079215_SLC1A3_NT.txt
# False
#
# ENSG00000087842_PIR_NT.txt
# True
#
# ENSG00000088833_NSFL1C_NT.txt
# True
#
# ENSG00000090060_PAPOLA_NT.txt
# False
#
# ENSG00000090539_CHRD_NT.txt
# False
#
# ENSG00000100280_AP1B1_NT.txt
# False
#
# ...
