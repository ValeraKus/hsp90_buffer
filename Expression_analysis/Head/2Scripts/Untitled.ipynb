# %%
files = !ls ../../Body/1_Raw/GTEx_Analysis_v7_eQTL/

# %%
files
# Out:
# ['Adipose_Subcutaneous.v7.egenes.txt.gz',
#  'Adipose_Subcutaneous.v7.signif_variant_gene_pairs.txt.gz',
#  'Adipose_Visceral_Omentum.v7.egenes.txt.gz',
#  'Adipose_Visceral_Omentum.v7.signif_variant_gene_pairs.txt.gz',
#  'Adrenal_Gland.v7.egenes.txt.gz',
#  'Adrenal_Gland.v7.signif_variant_gene_pairs.txt.gz',
#  'Artery_Aorta.v7.egenes.txt.gz',
#  'Artery_Aorta.v7.signif_variant_gene_pairs.txt.gz',
#  'Artery_Coronary.v7.egenes.txt.gz',
#  'Artery_Coronary.v7.signif_variant_gene_pairs.txt.gz',
#  'Artery_Tibial.v7.egenes.txt.gz',
#  'Artery_Tibial.v7.signif_variant_gene_pairs.txt.gz',
#  'Brain_Amygdala.v7.egenes.txt.gz',
#  'Brain_Amygdala.v7.signif_variant_gene_pairs.txt.gz',
#  'Brain_Anterior_cingulate_cortex_BA24.v7.egenes.txt.gz',
#  'Brain_Anterior_cingulate_cortex_BA24.v7.signif_variant_gene_pairs.txt.gz',
#  'Brain_Caudate_basal_ganglia.v7.egenes.txt.gz',
#  'Brain_Caudate_basal_ganglia.v7.signif_variant_gene_pairs.txt.gz',
# ...

# %%
path = '../../Body/1_Raw/GTEx_Analysis_v7_eQTL/'

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data = pd.DataFrame()
for i in range(len(files)):
    if '.egenes.txt.gz' in files[i]:
        tissue = files[i].replace('.v7.egenes.txt.gz', '')
        path_ = path + files[i]
        egen = pd.read_csv(path_, sep = '\t')
        egen['Tissue'] = tissue
        data = data.append(egen)
# Out:
# /home/lera/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (2,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1147964 entries, 0 to 20058
# Data columns (total 34 columns):
# gene_id                     1147964 non-null object
# gene_name                   1147964 non-null object
# gene_chr                    1147964 non-null object
# gene_start                  1147964 non-null int64
# gene_end                    1147964 non-null int64
# strand                      1147964 non-null object
# num_var                     1147964 non-null int64
# beta_shape1                 1147964 non-null float64
# beta_shape2                 1147964 non-null float64
# true_df                     1147964 non-null float64
# pval_true_df                1147964 non-null float64
# variant_id                  1147964 non-null object
# tss_distance                1147964 non-null int64
# chr                         1147964 non-null object
# pos                         1147964 non-null int64
# ref                         1147964 non-null object
# ...

# %%
data.describe().T
# Out:
#                             count          mean           std            min  \
# gene_start              1147964.0  7.383148e+07  5.561145e+07   5.810000e+03
# gene_end                1147964.0  7.388494e+07  5.561692e+07   1.436200e+04
# num_var                 1147964.0  7.200658e+03  2.247496e+03   9.700000e+01
# beta_shape1             1147964.0  1.039624e+00  2.448187e-02   8.782120e-01
# beta_shape2             1147964.0  8.499619e+02  3.924935e+02   6.610270e+01
# true_df                 1147964.0  1.553189e+02  8.105712e+01   4.212930e+01
# pval_true_df            1147964.0  8.108549e-04  1.414428e-03  3.180530e-173
# tss_distance            1147964.0 -4.795080e+03  4.797543e+05  -1.000000e+06
# pos                     1147964.0  7.385291e+07  5.561391e+07   1.397000e+03
# num_alt_per_site        1147964.0  1.049989e+00  2.720409e-01   1.000000e+00
# minor_allele_samples    1147964.0  5.700171e+01  6.594954e+01   1.000000e+00
# ...

# %%
# Out:
# 0        Adipose_Subcutaneous
# 1        Adipose_Subcutaneous
# 2        Adipose_Subcutaneous
# 3        Adipose_Subcutaneous
# 4        Adipose_Subcutaneous
# 5        Adipose_Subcutaneous
# 6        Adipose_Subcutaneous
# 7        Adipose_Subcutaneous
# 8        Adipose_Subcutaneous
# 9        Adipose_Subcutaneous
# 10       Adipose_Subcutaneous
# 11       Adipose_Subcutaneous
# 12       Adipose_Subcutaneous
# 13       Adipose_Subcutaneous
# 14       Adipose_Subcutaneous
# 15       Adipose_Subcutaneous
# 16       Adipose_Subcutaneous
# 17       Adipose_Subcutaneous
# 18       Adipose_Subcutaneous
# 19       Adipose_Subcutaneous
# 20       Adipose_Subcutaneous
# 21       Adipose_Subcutaneous
# 22       Adipose_Subcutaneous
# 23       Adipose_Subcutaneous
# 24       Adipose_Subcutaneous
# 25       Adipose_Subcutaneous
# 26       Adipose_Subcutaneous
# 27       Adipose_Subcutaneous
# 28       Adipose_Subcutaneous
# 29       Adipose_Subcutaneous
#                  ...
# ...
